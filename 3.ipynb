# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = plt.imread("tree.jpg")
plt.imshow(img)

# %%
import matplotlib.image as img  
image= img.imread("tree.jpg")
plt.imshow(image[:,:,1], cmap='gray', vmin=0, vmax=255, interpolation='None')
